# %%
import nibabel

# %%
img = nibabel.load('/sdata1/transform_CR_3xp_A.nii')

# %%
data = img.get_fdata()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data[:,:,300])

# %%
import utils

# %%
utils.save_mrc(data[::3,::3,::3], 'images/femur_test.mrc')
